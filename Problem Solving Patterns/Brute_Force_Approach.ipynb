# %% [markdown]
# Brute Force Approach
# ---

# %% [markdown]
# ### 🔍 **Definition of Brute Force Approach**
#
# The **Brute Force** approach is a straightforward method for solving problems by trying all possible solutions and selecting the correct or best one. It doesn't use any optimization techniques — it relies purely on **exhaustive search**.
#
# * Think of it as **"try everything and pick what works."**
#
# ---
#
# ### ⚙️ **How Brute Force Works**
#
# 1. **Generate all possible candidates**.
# 2. **Check each candidate** to see if it satisfies the problem's conditions.
# 3. **Return the solution** if found, or the best solution if multiple exist.
#
# This method is often used when:
#
# * The problem size is small.
# * There are no known better (optimized) algorithms.
# * Simplicity is more important than efficiency.
#
# ---
#
# ### 🧠 **Example: Brute Force for Finding a Target in an Array**
#
# **Problem:** Given an array and a target number, check if the number exists in the array.

# %%
def brute_force_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return True
    return False

# Example:
arr = [2, 4, 6, 8, 10]
target = 6
print(brute_force_search(arr, target))  # Output: True

# %% [markdown]
# ### 📦 **Another Example: Brute Force for Password Cracking**
#
# Suppose you're trying to guess a 3-digit password made of digits 0-9. Brute force would try every combination from `000` to `999`.
#
# There are **1000** possible combinations.
#
# ---
#
# ### ✅ **Advantages of Brute Force**
#
# 1. **Simplicity**: Easy to implement and understand.
# 2. **Guaranteed Results**: Will always find the solution if one exists.
# 3. **No Heuristics Needed**: Doesn’t require deep knowledge of the problem.
# 4. **Useful for Small Input Sizes**: Fast enough when the number of possibilities is low.
#
# ---
#
# ### ❌ **Disadvantages of Brute Force**
#
# 1. **Inefficient**: Time-consuming for large input sizes (exponential time in many cases).
# 2. **High Computational Cost**: Uses more CPU/memory resources.
# 3. **Not Scalable**: Fails to perform well as data size increases.
#
# ---
#
# ### 📊 **Time Complexity**
#
# Varies based on the problem, but is often:
#
# * **O(n!)**, **O(2ⁿ)**, or **O(n²)** in many brute force algorithms.
#
# For example:
#
# * Searching an array: **O(n)**
# * Solving Traveling Salesman Problem: **O(n!)**
#
# ---
#
# ### 🧾 **Use Cases Where Brute Force is Acceptable**
#
# * Solving puzzles like Sudoku or crosswords.
# * Cracking simple passwords.
# * Generating permutations/combinations.
# * Problems with a **small input size** or in **interview settings**.
#
# ---

# %% [markdown]
# ## Lets us solve some of the brute force problems

# %% [markdown]
# ## 🧮 **1. Problem: Find the Maximum Element in an Array**
#
# ### 📝 Problem Statement
#
# Given an array of integers, find the **maximum element** using brute force.
#
# ### 💡 Idea
#
# Check every element and keep track of the largest one.
#
# ### 🧠 Brute Force Logic
#
# * Compare each element with the current maximum.
# * Update the maximum when a larger value is found.
#
# ### 🧾 Code
#
# ```python
# def find_max(arr):
#     max_val = arr[0]
#
#     for num in arr:
#         if num > max_val:
#             max_val = num
#
#     return max_val
#
# # Example
# arr = [3, 9, 2, 7, 5]
# print(find_max(arr))   # Output: 9
# ```
#
# ### ⏱ Time Complexity
#
# **O(n)** — because every element is checked.
#
# ---
#
# ## 🔢 **2. Problem: Count Occurrences of a Target in an Array**
#
# ### 📝 Problem Statement
#
# Given an array and a target number, count how many times the target appears.
#
# ### 💡 Idea
#
# Loop through the whole array and count matches.
#
# ### 🧾 Code
#
# ```python
# def count_occurrences(arr, target):
#     count = 0
#     for num in arr:
#         if num == target:
#             count += 1
#     return count
#
# # Example
# arr = [1, 2, 3, 2, 4, 2]
# target = 2
# print(count_occurrences(arr, target))  # Output: 3
# ```
#
# ### ⏱ Time Complexity
#
# **O(n)** — loop through all elements.
#
# ---
#
# ## 🎯 **3. Problem: Two Sum (Brute Force Version)**
#
# ### 📝 Problem Statement
#
# Given an array of integers and a target value, return the indices of two numbers that add up to the target.
#
# ### 💡 Idea
#
# Try **every possible pair**.
# Pure brute force: no optimization.
#
# ### 🧠 Brute Force Logic
#
# * Pick element `i`
# * Pair it with every element `j > i`
# * Check if sum matches target
#
# ### 🧾 Code
#
# ```python
# def two_sum(arr, target):
#     for i in range(len(arr)):
#         for j in range(i + 1, len(arr)):
#             if arr[i] + arr[j] == target:
#                 return (i, j)
#
#     return None
#
# # Example
# arr = [2, 7, 11, 15]
# target = 9
# print(two_sum(arr, target))   # Output: (0, 1)
# ```
#
# ### ⏱ Time Complexity
#
# **O(n²)** — nested loops.
#
# ---
#
# ## 🧩 **4. Problem: Check if Array Contains Duplicates**
#
# ### 📝 Problem Statement
#
# Return `True` if any value appears at least twice.
#
# ### 💡 Idea
#
# Compare **every element with every other element**.
#
# ### 🧾 Code
#
# ```python
# def contains_duplicate(arr):
#     for i in range(len(arr)):
#         for j in range(i + 1, len(arr)):
#             if arr[i] == arr[j]:
#                 return True
#     return False
#
# # Example
# arr = [1, 2, 3, 4, 1]
# print(contains_duplicate(arr))   # Output: True
# ```
#
# ### ⏱ Time Complexity
#
# **O(n²)**
#
# ---
#
# ## 🧮 **5. Problem: Generate All Subarrays**
#
# ### 📝 Problem Statement
#
# Print all possible subarrays of an array.
#
# ### 💡 Idea
#
# Use two loops:
#
# * Start index
# * End index
#
# ### 🧾 Code
#
# ```python
# def print_subarrays(arr):
#     for i in range(len(arr)):
#         for j in range(i, len(arr)):
#             print(arr[i:j+1])
#
# # Example
# arr = [1, 2, 3]
# print_subarrays(arr)
# ```
#
# ### 📌 Output
#
# ```
# [1]
# [1, 2]
# [1, 2, 3]
# [2]
# [2, 3]
# [3]
# ```
#
# ### ⏱ Time Complexity
#
# **O(n²)** subarrays printed
#
# ---
#
# # 🚀 Summary Table — Brute Force Array Problems
#
# | Problem            | Technique   | Time Complexity |
# | ------------------ | ----------- | --------------- |
# | Search Element     | Linear Scan | O(n)            |
# | Find Max           | Linear Scan | O(n)            |
# | Count Occurrences  | Linear Scan | O(n)            |
# | Two Sum            | All Pairs   | O(n²)           |
# | Check Duplicates   | All Pairs   | O(n²)           |
# | Generate Subarrays | Nested Loop | O(n²)           |
#
# ---
#
# # 🎓 Key Learning — Why These Are “Brute Force”?
#
# Because:
#
# ✔ They **check everything**
# ✔ No shortcuts
# ✔ Simple logic
# ✔ Guaranteed correctness
# ❌ Not efficient for large inputs
#
# ---
#
# ## 📘 What You Can Add Next in Your Notebook
#
# You can make sections like:
#
# ### 🔹 Strings — Brute Force Problems
#
# * Check palindrome
# * Count vowels
# * Pattern matching
#
# ### 🔹 Recursion + Brute Force
#
# * Permutations
# * Subsets
# * Backtracking basics
#
# ### 🔹 Real-world Examples
#
# * Cracking numeric PIN
# * Password combinations
